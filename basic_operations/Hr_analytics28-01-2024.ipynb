# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('people.csv')

# %%
data
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
# HR- human resourse
#hr analytics->analysis made by hr by seeing some data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfactoryLevel      14999 non-null  float64
#  1   lastEvaluation         14999 non-null  float64
#  2   numberOfProjects       14999 non-null  int64
#  3   avgMonthlyHours        14999 non-null  int64
#  4   timeSpent.company      14999 non-null  int64
#  5   workAccident           14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotionInLast5years  14999 non-null  int64
#  8   dept                   14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
data.isnull().sum()
# Out:
# satisfactoryLevel        0
# lastEvaluation           0
# numberOfProjects         0
# avgMonthlyHours          0
# timeSpent.company        0
# workAccident             0
# left                     0
# promotionInLast5years    0
# dept                     0
# salary                   0
# dtype: int64

# %%
#duplicated values

# %%
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 14994     True
# 14995    False
# 14996    False
# 14997    False
# 14998    False
# Length: 14999, dtype: bool

# %%
data[data.duplicated()]
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 263                 0.46            0.57                 2              139
# 877                 0.37            0.51                 2              127
# 974                 0.42            0.53                 2              142
# 1017                0.40            0.50                 2              127
# 1241                0.10            0.85                 6              266
# ...                  ...             ...               ...              ...
# 14985               0.95            0.84                 3              270
# 14987               0.37            0.45                 2              126
# 14988               0.43            0.57                 2              157
# 14993               0.61            0.89                 3              242
# 14994               0.11            0.85                 7              275
#
# ...

# %%
data=data.drop_duplicates()

# %%
data
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14992               0.30            0.88                 5              245
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
data.describe()
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# count       11991.000000    11991.000000      11991.000000     11991.000000
# mean            0.629658        0.716683          3.802852       200.473522
# std             0.241070        0.168343          1.163238        48.727813
# min             0.090000        0.360000          2.000000        96.000000
# 25%             0.480000        0.570000          3.000000       157.000000
# 50%             0.660000        0.720000          4.000000       200.000000
# 75%             0.820000        0.860000          5.000000       243.000000
# max             1.000000        1.000000          7.000000       310.000000
#
#        timeSpent.company  workAccident          left  promotionInLast5years
# count       11991.000000  11991.000000  11991.000000           11991.000000
# mean            3.364857      0.154282      0.166041               0.016929
# ...

# %%
# Visual exploaration

# %%
# Create a bar cahrt to visualize employee turnover

# %%
sns.countplot(data=data,x='left')
# Out:
# <Axes: xlabel='left', ylabel='count'>

# %%
sns.countplot(data=data,x='left',palette=['green','red'])
# Out:
# C:\Users\shubham ekhande\AppData\Local\Temp\ipykernel_22232\893407977.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data,x='left',palette=['green','red'])
# <Axes: xlabel='left', ylabel='count'>

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=data,x='left',palette=['green','red'])
plt.title('employee turnover')
plt.xlabel('left the company')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=data,x='left',palette=['green','red'])
plt.title('employee turnover')
plt.xlabel('left the company')
plt.ylabel('count')
plt.xticks([0,1],['No','Yes'])
plt.show()

# %%
# inferece :-#turnover ratio is average we need to improve it

# %%
#create a histogram to visualize distibutio of satisfaction levels

# %%
plt.figure(figsize=(8,6))
sns.histplot(data=data,x='satisfactoryLevel',color='skyblue')
plt.title('distibution of satisfaction level of employees')
plt.xlabel('satisfaction level')
plt.ylabel('count')
plt.show()

# %%
# # biased column
# 1.satisfctory level:- biased if a employee is leaving he can give bad ratings
# 2.latevaluation:-a manager can rate a employee wrong
# 3.avgmonthlyours:-semi biased

# %%
# importan columns

# numberofprijects
# timespent.company
# workaccident
# left-> 0 person for not leaving,1 leaving
# promotioninlast5years
# dept 
# salary

# %%
#number of projects

fig=plt.figure(figsize=(5,4))
sns.countplot(data=data,x='numberOfProjects',hue='left')
# Out:
# <AxesSubplot:xlabel='numberOfProjects', ylabel='count'>

# %%
# inference:-number of projects can be between 3 or 4

# %%
data.corr()
# Out:
#                        satisfactoryLevel  lastEvaluation  numberOfProjects  \
# satisfactoryLevel               1.000000        0.095186         -0.133246
# lastEvaluation                  0.095186        1.000000          0.270256
# numberOfProjects               -0.133246        0.270256          1.000000
# avgMonthlyHours                -0.006252        0.264678          0.331516
# timeSpent.company              -0.152915        0.096829          0.188837
# workAccident                    0.039940       -0.005695         -0.005612
# left                           -0.350558        0.013520          0.030928
# promotionInLast5years           0.019789       -0.007206         -0.000544
#
#                        avgMonthlyHours  timeSpent.company  workAccident  \
# satisfactoryLevel            -0.006252          -0.152915      0.039940
# lastEvaluation                0.264678           0.096829     -0.005695
# numberOfProjects              0.331516           0.188837     -0.005612
# ...

# %%
plt.figure(figsize=(7,7))
sns.heatmap(data.corr(),cmap='rainbow',annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(7,7))
sns.heatmap(data.corr(),cmap='Blues',annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.histplot(x=data['numberOfProjects'],hue=data['left'])
# Out:
# <AxesSubplot:xlabel='numberOfProjects', ylabel='Count'>

# %%
new_df=data.select_dtypes(exclude=['object'])

# %%
new_df.corr()
# Out:
#                        satisfactoryLevel  lastEvaluation  numberOfProjects  \
# satisfactoryLevel               1.000000        0.095186         -0.133246
# lastEvaluation                  0.095186        1.000000          0.270256
# numberOfProjects               -0.133246        0.270256          1.000000
# avgMonthlyHours                -0.006252        0.264678          0.331516
# timeSpent.company              -0.152915        0.096829          0.188837
# workAccident                    0.039940       -0.005695         -0.005612
# left                           -0.350558        0.013520          0.030928
# promotionInLast5years           0.019789       -0.007206         -0.000544
#
#                        avgMonthlyHours  timeSpent.company  workAccident  \
# satisfactoryLevel            -0.006252          -0.152915      0.039940
# lastEvaluation                0.264678           0.096829     -0.005695
# numberOfProjects              0.331516           0.188837     -0.005612
# ...

# %%
#workaccident

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=data,x='workAccident',hue='left')
plt.xticks([0,1],['NO work accident','workaccident'])
# Out:
# ([<matplotlib.axis.XTick at 0x17ce7ff2640>,
# ...
#  [Text(0, 0, 'NO work accident'), Text(1, 0, 'workaccident')])

# %%
# inferences:- employees ar enot leaving just because of conflicts
# suggestion-nil

# %%
# promotion in last 5 years

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=data,x='promotionInLast5years',hue='left')
plt.title('promotion in last 5 years')
plt.ylabel('number of employees')
plt.xticks([0,1],['No promotion','got promotion'])
plt.show()

# %%
# Inferece:- people who are not getting promotion they are leaving
# suggestion:-Time to time promotions or reduce the period of giving the promotion
# train them to upgrade their skills and then fgive promotion based on there capability

# %%
#department check

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=data,x='dept',hue='left')
plt.show()

# %%
#inference:-people of sales,technical,support are leaving the company most

#suggestions:-
#give option to move to othe dept
#give them or inc the incentives
#for better team mangemnt organize team meetings to discuss whatever problems employees are facing
#have surveys on team basis 
#taking for team outings,lunch
#hybrid mode

# %%
#based on the salary

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=data,x='salary',hue='left')
plt.show()

# %%
# Inferences:- employees with low/medium salary are leaving the most
# suggestions:- regular sal hikes+promotion+incentives+project changes

# %%
sns.pairplot(data)

# %%
features=['dept','salary','numberOfProjects','timeSpent.company','workAccident']
features
# Out:
# ['dept', 'salary', 'numberOfProjects', 'timeSpent.company', 'workAccident']

# %%
fig=plt.subplots(figsize=(10,15))

for p,q in enumerate(features):
    plt.subplot(4,2,p+1)
    plt.subplots_adjust(hspace=1.0)
    sns.countplot(x=q,data=data,hue='left')
    plt.xticks(rotation=90)
