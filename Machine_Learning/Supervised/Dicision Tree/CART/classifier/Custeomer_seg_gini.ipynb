# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("customer_segmentation_cart.csv")

# %%
df.head()
# Out:
#    monthly_spend  visit_frequency  discount_usage  returns_count  \
# 0          34893               17               0              2
# 1          43582               27               8              3
# 2           8473                7               7              0
# 3           9077                8               3              0
# 4           8570                3               9              3
#
#    membership_years  segment_high_value
# 0                 3                   1
# 1                 1                   1
# 2                 1                   0
# 3                 8                   0
# 4                 4                   0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   monthly_spend       200 non-null    int64
#  1   visit_frequency     200 non-null    int64
#  2   discount_usage      200 non-null    int64
#  3   returns_count       200 non-null    int64
#  4   membership_years    200 non-null    int64
#  5   segment_high_value  200 non-null    int64
# dtypes: int64(6)
# memory usage: 9.5 KB

# %%
#features
X = df.drop("segment_high_value", axis=1)
y = df["segment_high_value"]

# %%
#train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.3,
    random_state=42
)

# %%
#model
model = DecisionTreeClassifier(
    criterion="gini",   
    max_depth=4,           # Pruning
    min_samples_split=2
)

model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=4)

# %%
y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7833333333333333

# %%
df.head()
# Out:
#    monthly_spend  visit_frequency  discount_usage  returns_count  \
# 0          34893               17               0              2
# 1          43582               27               8              3
# 2           8473                7               7              0
# 3           9077                8               3              0
# 4           8570                3               9              3
#
#    membership_years  segment_high_value
# 0                 3                   1
# 1                 1                   1
# 2                 1                   0
# 3                 8                   0
# 4                 4                   0

# %%
# New cust
new_applicant = pd.DataFrame([{
    'monthly_spend' : 38, 
    'visit_frequency' : 5000, 
    'discount_usage' : 100, 
    'returns_count' : 10,
    'membership_years' :5
}])
prediction = model.predict(new_applicant)

if prediction == 1:
    print("High value")
else:
    print("Not high value")
# Out:
# High value
