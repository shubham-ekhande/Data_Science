# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("environmental_pca_dataset.csv")
df.head()
# Out:
#    Temperature_C  Humidity_Percent  Rainfall_mm  Wind_Speed_kmph  \
# 0       9.075724         25.928434   265.828031        33.393395
# 1       5.332798         50.037514    58.996075        46.660254
# 2      22.343312         84.305164   221.227826        13.274820
# 3       8.705019         54.677779    85.955865        30.573181
# 4      34.935374         99.774588   240.792094        33.924998
#
#    Air_Pressure_hPa     CO2_ppm  Solar_Radiation_Wm2
# 0       1033.292972  312.239808           236.300970
# 1       1004.029653  338.788739           489.494336
# 2       1034.466591  304.177836           636.111842
# 3        993.130171  394.706299           172.553865
# 4        987.904049  363.959754           945.611730

# %%
#scaling data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df)

# %%
#PCA
pca = PCA()
X_pca = pca.fit_transform(X_scaled)

# %%
print("Explained Varience Ratio:")
print(pca.explained_variance_ratio_)
# Out:
# Explained Varience Ratio:
# [0.19161309 0.16140398 0.15479013 0.15086872 0.12516055 0.11384568
#  0.10231784]

# %%
print("Commulative Varience:")
print(np.cumsum(pca.explained_variance_ratio_))
# Out:
# Commulative Varience:
# [0.19161309 0.35301707 0.5078072  0.65867593 0.78383648 0.89768216
#  1.        ]

# %%
pca = PCA(n_components=5)
X_reduced = pca.fit_transform(X_scaled)

print("Original Shape:", X_scaled.shape)
print("Reduced Shape:", X_reduced.shape)
# Out:
# Original Shape: (200, 7)
# Reduced Shape: (200, 5)

# %%
plt.figure()
plt.scatter(X_reduced[:, 0], X_reduced[:, 2])
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("Customer Behavior After PCA")
plt.show()
