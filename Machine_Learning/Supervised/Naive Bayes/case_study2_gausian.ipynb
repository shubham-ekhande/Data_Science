# %%
import pandas as pd
import numpy as np
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = {
    "Time_Spent": [5, 10, 15, 20, 3, 25, 8, 18],
    "Pages_Viewed": [2, 4, 6, 8, 1, 9, 3, 7],
    "Discount": [0, 5, 10, 15, 0, 20, 5, 10],
    "Purchase": [0, 0, 1, 1, 0, 1, 0, 1]
}

df = pd.DataFrame(data)

# %%
X = df[["Time_Spent", "Pages_Viewed", "Discount"]]
y = df["Purchase"]

model = GaussianNB()
model.fit(X, y)
# Out:
# GaussianNB()

# %%
new_customer = [[12, 5, 10]]
prediction = model.predict(new_customer)

print("Will Purchase:", "Yes" if prediction[0] == 1 else "No")
# Out:
# Will Purchase: Yes
# C:\ProgramData\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(

# %%
sns.scatterplot(
    data=df,
    x="Time_Spent",
    y="Pages_Viewed",
    hue="Purchase",
    palette="coolwarm",
    s=100
)
plt.title("Customer Behavior vs Purchase")
plt.show()
