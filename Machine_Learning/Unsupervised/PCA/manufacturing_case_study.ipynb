# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("manufacturing_pca_dataset.csv")
df.head()
# Out:
#    Machine_Temperature  Pressure_Level  Production_Speed  Vibration_Level  \
# 0                   40              59               282         4.601521
# 1                  100              78               387         3.042987
# 2                   82              78               406         4.710289
# 3                   81              67               399         4.151511
# 4                   64              60               181         3.368160
#
#    Energy_Consumption  Material_Thickness  Defect_Count
# 0                3496            2.171339             5
# 1                2866            1.696330             3
# 2                1834            3.407406             3
# 3                2203            2.747002             5
# 4                2725            1.697087             6

# %%
#scaling data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df)

# %%
#PCA
pca = PCA()
X_pca = pca.fit_transform(X_scaled)

# %%
print("Explained Varience Ratio:")
print(pca.explained_variance_ratio_)
# Out:
# Explained Varience Ratio:
# [0.18644963 0.16531255 0.15071155 0.14360136 0.12849849 0.11918239
#  0.10624404]

# %%
print("Commulative Varience:")
print(np.cumsum(pca.explained_variance_ratio_))
# Out:
# Commulative Varience:
# [0.18644963 0.35176218 0.50247373 0.64607508 0.77457357 0.89375596
#  1.        ]

# %%
pca = PCA(n_components=5)
X_reduced = pca.fit_transform(X_scaled)

print("Original Shape:", X_scaled.shape)
print("Reduced Shape:", X_reduced.shape)
# Out:
# Original Shape: (200, 7)
# Reduced Shape: (200, 5)

# %%
plt.figure()
plt.scatter(X_reduced[:, 0], X_reduced[:, 1])
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("Customer Behavior After PCA")
plt.show()
