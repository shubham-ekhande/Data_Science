# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("electricity_theft_random_forest.csv")
df.head()
# Out:
#    monthly_units  avg_daily_units  meter_variance  billing_delay_days  \
# 0            200               13            1.66                  61
# 1            171               26            1.67                  59
# 2            776               10            2.53                  11
# 3            192               15            0.77                  45
# 4            423               22            2.00                  35
#
#    past_theft_history  theft_detected
# 0                   0               1
# 1                   0               1
# 2                   0               0
# 3                   0               0
# 4                   1               1

# %%
X = df.drop("theft_detected", axis=1)
y = df["theft_detected"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
model = RandomForestClassifier(
    n_estimators=200,
    max_depth=8,
    random_state=42
)

model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=8, n_estimators=200, random_state=42)

# %%
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9733333333333334

# %%
df.head()
# Out:
#    monthly_units  avg_daily_units  meter_variance  billing_delay_days  \
# 0            200               13            1.66                  61
# 1            171               26            1.67                  59
# 2            776               10            2.53                  11
# 3            192               15            0.77                  45
# 4            423               22            2.00                  35
#
#    past_theft_history  theft_detected
# 0                   0               1
# 1                   0               1
# 2                   0               0
# 3                   0               0
# 4                   1               1

# %%
# New electricity meter data (must match training columns)
new_meter = pd.DataFrame([{
    'monthly_units': 125,
    'avg_daily_units': 4.1,
    'meter_variance': 0.38,
    'billing_delay_days': 6,
    'past_theft_history': 1
}])

prediction = model.predict(new_meter)

print("Electricity Theft Detected (1 = Yes, 0 = No):", prediction[0])
# Out:
# Electricity Theft Detected (1 = Yes, 0 = No): 0
