# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("social_media_pca_dataset.csv")
df.head()
# Out:
#    Likes  Comments  Shares  Watch_Time_Seconds  Click_Through_Rate  \
# 0    847       386     191                 770            0.075576
# 1    386       425     266                 508            0.318483
# 2    876       274     146                1787            0.036623
# 3    258       200     126                1498            0.376836
# 4    282       283      45                1724            0.165618
#
#    Profile_Visits  Post_Frequency
# 0             259               8
# 1             619              17
# 2             796              16
# 3             570              10
# 4             124              10

# %%
#scaling data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df)

# %%
#PCA
pca = PCA()
X_pca = pca.fit_transform(X_scaled)

# %%
print("Explained Varience Ratio:")
print(pca.explained_variance_ratio_)
# Out:
# Explained Varience Ratio:
# [0.16893038 0.16145744 0.15571316 0.14097957 0.13835036 0.12275255
#  0.11181655]

# %%
print("Commulative Varience:")
print(np.cumsum(pca.explained_variance_ratio_))
# Out:
# Commulative Varience:
# [0.16893038 0.33038782 0.48610098 0.62708054 0.7654309  0.88818345
#  1.        ]

# %%
pca = PCA(n_components=5)
X_reduced = pca.fit_transform(X_scaled)

print("Original Shape:", X_scaled.shape)
print("Reduced Shape:", X_reduced.shape)
# Out:
# Original Shape: (200, 7)
# Reduced Shape: (200, 5)

# %%
plt.figure()
plt.scatter(X_reduced[:, 0], X_reduced[:, 1])
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("Customer Behavior After PCA")
plt.show()
