# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("crop_yield_tree_rf.csv")
df.head()
# Out:
#    rainfall_mm  temperature_c  soil_quality_index  fertilizer_kg  \
# 0          830             26                   9            302
# 1          611             30                   3            166
# 2         1294             28                   4            226
# 3         1332             19                   3            207
# 4         1285             41                   8            291
#
#    irrigation_score yield_category
# 0                 4           High
# 1                 2            Low
# 2                 8         Medium
# 3                 8         Medium
# 4                 2           High

# %%
X = df.drop("yield_category", axis=1)
y = df["yield_category"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
dt_model = DecisionTreeClassifier(
    criterion="gini",
    max_depth=5,
    random_state=42
)

dt_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=42)

# %%
dt_pred = dt_model.predict(X_test)
print("Decision Tree Accuracy:", accuracy_score(y_test, dt_pred))
# Out:
# Decision Tree Accuracy: 0.7333333333333333

# %%
rf_model = RandomForestClassifier(
    n_estimators=200,
    max_depth=8,
    random_state=42
)

rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=8, n_estimators=200, random_state=42)

# %%
rf_pred = rf_model.predict(X_test)
print("Random Forest Accuracy:", accuracy_score(y_test, rf_pred))
# Out:
# Random Forest Accuracy: 0.8533333333333334

# %%
df.head()
# Out:
#    rainfall_mm  temperature_c  soil_quality_index  fertilizer_kg  \
# 0          830             26                   9            302
# 1          611             30                   3            166
# 2         1294             28                   4            226
# 3         1332             19                   3            207
# 4         1285             41                   8            291
#
#    irrigation_score yield_category
# 0                 4           High
# 1                 2            Low
# 2                 8         Medium
# 3                 8         Medium
# 4                 2           High

# %%
# New farm data
new_farm = pd.DataFrame([{
    'rainfall_mm': 780,
    'temperature_c': 26,
    'soil_quality_index': 6.8,
    'fertilizer_kg': 120,
    'irrigation_score': 3
}])

print("Decision Tree Prediction:", dt_model.predict(new_farm)[0])
print("Random Forest Prediction:", rf_model.predict(new_farm)[0])
# Out:
# Decision Tree Prediction: Low
# Random Forest Prediction: Low

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(200,100))
plot_tree(dt_model)
plt.show()
