# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("ecommerce_pca_dataset.csv")
df.head()
# Out:
#    Products_Viewed  Products_Clicked  Products_Purchased  Time_Spent_Seconds  \
# 0               39                24                   4                 186
# 1               29                 9                   6                 405
# 2               15                20                   0                 454
# 3               43                17                   2                 242
# 4                8                17                   1                  85
#
#    Cart_Additions  Wishlist_Additions  Product_Ratings
# 0               7                   7                2
# 1              14                   5                3
# 2              11                   1                2
# 3              13                   3                3
# 4               6                   3                1

# %%
#scaling data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df)

# %%
#PCA
pca = PCA()
X_pca = pca.fit_transform(X_scaled)

# %%
print("Explained Varience Ratio:")
print(pca.explained_variance_ratio_)
# Out:
# Explained Varience Ratio:
# [0.18268742 0.17501762 0.14932325 0.14121789 0.13131638 0.11747822
#  0.10295923]

# %%
print("Commulative Varience:")
print(np.cumsum(pca.explained_variance_ratio_))
# Out:
# Commulative Varience:
# [0.18268742 0.35770504 0.50702828 0.64824618 0.77956255 0.89704077
#  1.        ]

# %%
pca = PCA(n_components=5)
X_reduced = pca.fit_transform(X_scaled)

print("Original Shape:", X_scaled.shape)
print("Reduced Shape:", X_reduced.shape)
# Out:
# Original Shape: (200, 7)
# Reduced Shape: (200, 5)

# %%
plt.figure()
plt.scatter(X_reduced[:, 0], X_reduced[:, 1])
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("Customer Behavior After PCA")
plt.show()
